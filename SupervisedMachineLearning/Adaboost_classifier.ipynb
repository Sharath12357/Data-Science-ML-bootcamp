# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('Travel.csv')

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male       2916
# Female     1817
# Fe Male     155
# Name: count, dtype: int64

# %%
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married      2340
# Divorced      950
# Single        916
# Unmarried     682
# Name: count, dtype: int64

# %%
df['TypeofContact'].value_counts()
# Out:
# TypeofContact
# Self Enquiry       3444
# Company Invited    1419
# Name: count, dtype: int64

# %%
df['Gender']=df['Gender'].replace('Fe Male',"Female")

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      2916
# Female    1972
# Name: count, dtype: int64

# %%
df['MaritalStatus']=df['MaritalStatus'].replace('Single','Unmarried')

# %%
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married      2340
# Unmarried    1598
# Divorced      950
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
#Checking the Null values
#Imputation technique

# %%
df['Age'].fillna(df['Age'].median(),inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df['Age'].fillna(df['Age'].median(),inplace=True)
#
# File c:\Users\sharath R\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6231, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6223 @doc(make_doc("median", ndim=1))
#    6224 def median(
#    6225     self,
#    (...)
#    6229     **kwargs,
#    6230 ):
# -> 6231     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\sharath R\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:11995, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11988 def median(
#   11989     self,
#   11990     axis: Axis | None = 0,
#    (...)
#   11993     **kwargs,
#   11994 ) -> Series | float:
# > 11995     return self._stat_function(
# ...

# %%
df['TypeofContact'].fillna(df['TypeofContact'].mode()[0],inplace=True)

# %%
df['DurationOfPitch'].fillna(df['DurationOfPitch'].median(),inplace=True)

# %%
df['NumberOfFollowups'].fillna(df['NumberOfFollowups'].mode()[0],inplace=True)

# %%
df['PreferredPropertyStar'].fillna(df['PreferredPropertyStar'].median(),inplace=True)

# %%
df['NumberOfTrips'].fillna(df['NumberOfTrips'].mode()[0],inplace=True)

# %%
df['NumberOfChildrenVisiting'].fillna(df['NumberOfChildrenVisiting'].mode()[0],inplace=True)

# %%
df['MonthlyIncome'].fillna(df['MonthlyIncome'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64

# %%
#Check the how many type for numeric, categorical and descrite date is present in this dataset

# %%
df['TotalVisiting']=df['NumberOfChildrenVisiting']+df["NumberOfPersonVisiting"]
df.drop(columns=['NumberOfPersonVisiting', 'NumberOfChildrenVisiting'], axis=1, inplace=True)

# %%
num_features = [feature for feature in df.columns if df[feature].dtype != 'O']
print('Num of Numerical Features :', len(num_features))
# Out:
# Num of Numerical Features : 12

# %%
df.drop('CustomerID', inplace=True, axis=1)

# %%
catergorical_feature=[feature for feature in df.columns if df[feature].dtype=='O']
print('categorical_feature:',len(catergorical_feature))
# Out:
# categorical_feature: 7

# %%
#Train Test split Model Training

# %%
from sklearn.model_selection import train_test_split
X=df.drop(['ProdTaken'],axis=1)
y=df['ProdTaken']

# %%
y.value_counts()
# Out:
# ProdTaken
# 0    3968
# 1     920
# Name: count, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
#Create column transformer with 3 types of transformer
cat_features=X.select_dtypes(include="object").columns
num_features=X.select_dtypes(exclude="object").columns

from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer
numeric_transformer = StandardScaler()
oh_transformer = OneHotEncoder(drop='first')

preprocessor=ColumnTransformer(
    [
        ("OneHotEncode",oh_transformer,cat_features),
        ("StandardScaler", numeric_transformer,num_features)

    ]

)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('OneHotEncode', OneHotEncoder(drop='first'),
#                                  Index(['Age', 'TypeofContact', 'Occupation', 'Gender', 'ProductPitched',
#        'MaritalStatus', 'Designation'],
#       dtype='object')),
#                                 ('StandardScaler', StandardScaler(),
#                                  Index(['CityTier', 'DurationOfPitch', 'NumberOfFollowups',
#        'PreferredPropertyStar', 'NumberOfTrips', 'Passport',
#        'PitchSatisfactionScore', 'OwnCar', 'MonthlyIncome', 'TotalVisiting'],
#       dtype='object'))])

# %%
#ADABOOST CLASSIFIER

# %%
X_train=preprocessor.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\sharath R\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_encode.py:174, in _unique_python(values, return_inverse, return_counts)
#     172 uniques_set, missing_values = _extract_missing(uniques_set)
# --> 174 uniques = sorted(uniques_set)
#     175 uniques.extend(missing_values.to_list())
#
# TypeError: '<' not supported between instances of 'method' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 X_train=preprocessor.fit_transform(X_train)
#
# File c:\Users\sharath R\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay,recall_score,precision_score,f1_score, roc_auc_score,roc_curve
